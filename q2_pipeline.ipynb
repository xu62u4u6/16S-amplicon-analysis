# %%
import os
from qiime2 import Visualization, Artifact, Metadata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
# create output dir
if not os.path.isdir("output/"):
    os.mkdir("output/")
    for dir_name in ["qza", "qzv", "table", "plot", "json"]:
        os.mkdir(os.path.join("output", dir_name))

# %%
# import fastq.gz
seq_path = "seq"

if not os.path.isfile("output/qza/raw_seqs.qza"):
    raw_seqs = Artifact.import_data("SampleData[PairedEndSequencesWithQuality]", 
                                    f"./{seq_path}/", 
                                    "CasavaOneEightSingleLanePerSampleDirFmt")
    raw_seqs.save("output/qza/raw_seqs")
else:
    raw_seqs = Artifact.load("output/qza/raw_seqs.qza")

# %%
# QC info
from qiime2.plugins.demux.visualizers import summarize 
seqs_summarize = summarize(raw_seqs)[0] # 用於判斷定序品質
seqs_summarize.save("output/qzv/seqs_summarize") # save qzv
seqs_summarize.export_data("output/seqs_summarize")
seqs_summarize
# Out:
# /home/blue_pc/miniconda3/envs/qiime2/lib/python3.8/site-packages/q2_demux/_summarize/_visualizer.py:191: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   context['result_data'] = context['result_data'].append(df)
# /home/blue_pc/miniconda3/envs/qiime2/lib/python3.8/site-packages/q2_demux/_summarize/_visualizer.py:191: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   context['result_data'] = context['result_data'].append(df)
# <visualization: Visualization uuid: 5a8b53cc-be7d-4340-a3de-9d00484bde4e>

# %%
# dada2 denoise 
# 請參考上面資料來決定切除到哪個位置
from qiime2.plugins.dada2.methods import denoise_paired # dada2去雜訊
trunc_len = 270
trim = 15
feature_table, representative_seqs, denoising_stats = denoise_paired(raw_seqs, 
                                              trunc_len_f = trunc_len,
                                              trunc_len_r = trunc_len, 
                                              trim_left_f = trim, 
                                              trim_left_r = trim,
                                              n_threads = 0,
                                              )
# Out:
# Running external command line application(s). This may print messages to stdout and/or stderr.
# The command(s) being run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: run_dada.R --input_directory /tmp/tmpsrcvv1zm/forward --input_directory_reverse /tmp/tmpsrcvv1zm/reverse --output_path /tmp/tmpsrcvv1zm/output.tsv.biom --output_track /tmp/tmpsrcvv1zm/track.tsv --filtered_directory /tmp/tmpsrcvv1zm/filt_f --filtered_directory_reverse /tmp/tmpsrcvv1zm/filt_r --truncation_length 270 --truncation_length_reverse 270 --trim_left 15 --trim_left_reverse 15 --max_expected_errors 2.0 --max_expected_errors_reverse 2.0 --truncation_quality_score 2 --min_overlap 12 --pooling_method independent --chimera_method consensus --min_parental_fold 1.0 --allow_one_off False --num_threads 0 --learn_min_reads 1000000
#
# R version 4.1.3 (2022-03-10)
# Loading required package: Rcpp
# DADA2: 1.22.0 / Rcpp: 1.0.9 / RcppParallel: 5.1.5
# 2) Filtering
# The filter removed all reads: /tmp/tmpsrcvv1zm/filt_f/1_S11_L001_R1_001.fastq.gz and /tmp/tmpsrcvv1zm/filt_r/1_S11_L001_R2_001.fastq.gz not written.
# Some input samples had no reads pass the filter.
# x..........................
# 3) Learning Error Rates
# 268440285 total bases in 1052707 reads from 9 samples will be used for learning the error rates.
# 268440285 total bases in 1052707 reads from 9 samples will be used for learning the error rates.
# 3) Denoise samples ..........................
# ..........................
# 5) Remove chimeras (method = consensus)
# 6) Report read numbers through the pipeline
# 7) Write output

# %%
# stats_df
stats_df = denoising_stats.view(Metadata).to_dataframe()
stats_df.columns = pd.Series(stats_df.columns).apply(lambda x: x.replace(" ", "_"))
stats_df.index = pd.Series(stats_df.index).apply(lambda x: x.split("_", 1)[0]).astype(np.int64).sort_values()
stats_df.to_csv(f"output/table/stats_df_{trunc_len}_{trim}.csv")

# stats bar plot
fig, ax = plt.subplots(1, 1)

ax.bar(range(len(stats_df.index)), 100, color="gray", label="input")
for bar_title in ["percentage_of_input_passed_filter", "percentage_of_input_merged", "percentage_of_input_non-chimeric"]:
    ax.bar(range(len(stats_df.index)), stats_df.loc[:, bar_title], label= bar_title)
plt.xticks(range(len(stats_df.index)), stats_df.index)
ax.legend(loc='lower right')
fig.tight_layout()
fig.show()
fig.savefig(f"output/plot/stats_df_bar_plot_{trunc_len}_{trim}.png", format='png', bbox_inches='tight', dpi=600) # 透明背景

# %%
# save data
feature_table.save("output/qza/feature_table")
feature_table.export_data("output/table")
representative_seqs.save("output/qza/representative_seqs")
representative_seqs.export_data("output/representative_seqs")
denoising_stats.save("output/qza/denoising_stats")

# %%
representative_seqs = Artifact.load("/home/blue_pc/code/CYH/output/qza/representative_seqs.qza")
silva = Artifact.load("/home/blue_pc/ref/silva-138-99-515-806-nb-classifier.qza")

# %%
from qiime2.plugins.feature_classifier.methods import classify_sklearn
SKLEARN_USE_ALL_CPU = -2
classification = classify_sklearn(reads=representative_seqs, classifier=silva, n_jobs=SKLEARN_USE_ALL_CPU)
classification.save("output/qza/classification")

# %%
from qiime2.plugins.phylogeny.pipelines import align_to_tree_mafft_fasttree
alignment, masked_alignment, tree, rooted_tree  = align_to_tree_mafft_fasttree(representative_seqs)
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: mafft --preservecase --inputorder --thread 1 /tmp/qiime2/blue_pc/data/bd8010fc-c9a3-4f50-8216-e91137d75026/data/dna-sequences.fasta
# inputfile = orig
# 2242 x 496 - 256 d
# nthread = 1
# nthreadpair = 1
# nthreadtb = 1
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#  2201 / 2242 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#  2240 / 2242
# done.
#
# Progressive alignment 1/2...
# STEP  2001 / 2241 (thread    0)
# Reallocating..done. *alloclen = 2024
# STEP  2201 / 2241 (thread    0)
# Reallocating..done. *alloclen = 3117
#
# done.
#
# Making a distance matrix from msa..
#  2200 / 2242 (thread    0)
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#  2240 / 2242
# done.
#
# Progressive alignment 2/2...
# STEP  2101 / 2241 (thread    0)
# Reallocating..done. *alloclen = 2007
# STEP  2201 / 2241 (thread    0)
# Reallocating..done. *alloclen = 3079
#
# done.
#
# disttbfast (nuc) Version 7.505
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 1 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.
# Running external command line application. This may print messages to stdout and/or stderr.
# The command being run is below. This command cannot be manually re-run as it will depend on temporary files that no longer exist.
#
# Command: FastTree -quote -nt /tmp/qiime2/blue_pc/data/13fa901f-d96b-44f6-b8c4-ca04f73651ee/data/aligned-dna-sequences.fasta
# FastTree Version 2.1.11 Double precision (No SSE3)
# Alignment: /tmp/qiime2/blue_pc/data/13fa901f-d96b-44f6-b8c4-ca04f73651ee/data/aligned-dna-sequences.fasta
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jukes-Cantor, CAT approximation with 20 rate categories
#       0.25 seconds: Top hits for    374 of   2078 seqs (at seed    100)
#       0.37 seconds: Top hits for    827 of   2078 seqs (at seed    500)
#       0.47 seconds: Top hits for   1146 of   2078 seqs (at seed    900)
#       0.60 seconds: Top hits for   1598 of   2078 seqs (at seed   1200)
#       0.70 seconds: Top hits for   1836 of   2078 seqs (at seed   1600)
#       0.84 seconds: Top hits for   2066 of   2078 seqs (at seed   2000)
#       1.11 seconds: Joined    100 of   2075
#       1.51 seconds: Joined    200 of   2075
#       1.75 seconds: Joined    300 of   2075
#       2.03 seconds: Joined    400 of   2075
#       2.29 seconds: Joined    500 of   2075
#       2.64 seconds: Joined    600 of   2075
#       2.96 seconds: Joined    700 of   2075
#       3.33 seconds: Joined    800 of   2075
#       3.61 seconds: Joined    900 of   2075
#       3.88 seconds: Joined   1000 of   2075
#       4.14 seconds: Joined   1100 of   2075
#       4.39 seconds: Joined   1200 of   2075
#       4.60 seconds: Joined   1300 of   2075
#       4.81 seconds: Joined   1400 of   2075
#       4.99 seconds: Joined   1500 of   2075
#       5.17 seconds: Joined   1600 of   2075
#       5.33 seconds: Joined   1700 of   2075
#       5.49 seconds: Joined   1800 of   2075
#       5.59 seconds: Joined   1900 of   2075
#       5.74 seconds: Joined   2000 of   2075
# Initial topology in 5.81 seconds
# Refining topology: 44 rounds ME-NNIs, 2 rounds ME-SPRs, 22 rounds ML-NNIs
#       5.84 seconds: ME NNI round 1 of 44, 401 of 2076 splits, 80 changes (max delta 0.049)
#       5.95 seconds: ME NNI round 1 of 44, 1701 of 2076 splits, 378 changes (max delta 0.445)
#       6.05 seconds: ME NNI round 2 of 44, 601 of 2076 splits, 77 changes (max delta 0.016)
#       6.16 seconds: ME NNI round 2 of 44, 1701 of 2076 splits, 216 changes (max delta 0.039)
#       6.26 seconds: ME NNI round 3 of 44, 701 of 2076 splits, 46 changes (max delta 0.022)
#       6.37 seconds: ME NNI round 4 of 44, 101 of 2076 splits, 5 changes (max delta 0.000)
#       6.48 seconds: ME NNI round 5 of 44, 201 of 2076 splits, 9 changes (max delta 0.004)
#       6.59 seconds: ME NNI round 7 of 44, 201 of 2076 splits, 10 changes (max delta 0.044)
#       6.78 seconds: SPR round   1 of   2, 101 of 4154 nodes
#       6.92 seconds: SPR round   1 of   2, 201 of 4154 nodes
#       7.03 seconds: SPR round   1 of   2, 301 of 4154 nodes
#       7.16 seconds: SPR round   1 of   2, 401 of 4154 nodes
#       7.29 seconds: SPR round   1 of   2, 501 of 4154 nodes
#       7.43 seconds: SPR round   1 of   2, 601 of 4154 nodes
#       7.56 seconds: SPR round   1 of   2, 701 of 4154 nodes
#       7.72 seconds: SPR round   1 of   2, 801 of 4154 nodes
#       7.90 seconds: SPR round   1 of   2, 901 of 4154 nodes
#       8.04 seconds: SPR round   1 of   2, 1001 of 4154 nodes
#       8.19 seconds: SPR round   1 of   2, 1101 of 4154 nodes
#       8.35 seconds: SPR round   1 of   2, 1201 of 4154 nodes
#       8.50 seconds: SPR round   1 of   2, 1301 of 4154 nodes
#       8.62 seconds: SPR round   1 of   2, 1401 of 4154 nodes
#       8.79 seconds: SPR round   1 of   2, 1501 of 4154 nodes
#       8.97 seconds: SPR round   1 of   2, 1601 of 4154 nodes
#       9.13 seconds: SPR round   1 of   2, 1701 of 4154 nodes
#       9.27 seconds: SPR round   1 of   2, 1801 of 4154 nodes
#       9.40 seconds: SPR round   1 of   2, 1901 of 4154 nodes
#       9.54 seconds: SPR round   1 of   2, 2001 of 4154 nodes
#       9.68 seconds: SPR round   1 of   2, 2101 of 4154 nodes
#       9.80 seconds: SPR round   1 of   2, 2201 of 4154 nodes
#       9.93 seconds: SPR round   1 of   2, 2301 of 4154 nodes
#      10.06 seconds: SPR round   1 of   2, 2401 of 4154 nodes
#      10.18 seconds: SPR round   1 of   2, 2501 of 4154 nodes
#      10.30 seconds: SPR round   1 of   2, 2601 of 4154 nodes
#      10.43 seconds: SPR round   1 of   2, 2701 of 4154 nodes
#      10.54 seconds: SPR round   1 of   2, 2801 of 4154 nodes
#      10.67 seconds: SPR round   1 of   2, 2901 of 4154 nodes
#      10.83 seconds: SPR round   1 of   2, 3001 of 4154 nodes
#      10.96 seconds: SPR round   1 of   2, 3101 of 4154 nodes
#      11.11 seconds: SPR round   1 of   2, 3201 of 4154 nodes
#      11.30 seconds: SPR round   1 of   2, 3301 of 4154 nodes
#      11.46 seconds: SPR round   1 of   2, 3401 of 4154 nodes
#      11.69 seconds: SPR round   1 of   2, 3501 of 4154 nodes
#      11.90 seconds: SPR round   1 of   2, 3601 of 4154 nodes
#      12.12 seconds: SPR round   1 of   2, 3701 of 4154 nodes
#      12.34 seconds: SPR round   1 of   2, 3801 of 4154 nodes
#      12.57 seconds: SPR round   1 of   2, 3901 of 4154 nodes
#      12.70 seconds: SPR round   1 of   2, 4001 of 4154 nodes
#      12.84 seconds: SPR round   1 of   2, 4101 of 4154 nodes
#      12.94 seconds: ME NNI round 15 of 44, 301 of 2076 splits, 3 changes (max delta 0.003)
#      13.04 seconds: ME NNI round 15 of 44, 1701 of 2076 splits, 30 changes (max delta 0.024)
#      13.15 seconds: ME NNI round 16 of 44, 1001 of 2076 splits, 7 changes (max delta 0.000)
#      13.25 seconds: ME NNI round 18 of 44, 101 of 2076 splits, 1 changes (max delta 0.000)
#      13.38 seconds: SPR round   2 of   2, 101 of 4154 nodes
#      13.48 seconds: SPR round   2 of   2, 201 of 4154 nodes
#      13.60 seconds: SPR round   2 of   2, 301 of 4154 nodes
#      13.73 seconds: SPR round   2 of   2, 401 of 4154 nodes
#      13.85 seconds: SPR round   2 of   2, 501 of 4154 nodes
#      13.97 seconds: SPR round   2 of   2, 601 of 4154 nodes
#      14.11 seconds: SPR round   2 of   2, 701 of 4154 nodes
#      14.26 seconds: SPR round   2 of   2, 801 of 4154 nodes
#      14.38 seconds: SPR round   2 of   2, 901 of 4154 nodes
#      14.51 seconds: SPR round   2 of   2, 1001 of 4154 nodes
#      14.66 seconds: SPR round   2 of   2, 1101 of 4154 nodes
#      14.79 seconds: SPR round   2 of   2, 1201 of 4154 nodes
#      14.91 seconds: SPR round   2 of   2, 1301 of 4154 nodes
#      15.03 seconds: SPR round   2 of   2, 1401 of 4154 nodes
#      15.16 seconds: SPR round   2 of   2, 1501 of 4154 nodes
#      15.32 seconds: SPR round   2 of   2, 1601 of 4154 nodes
#      15.44 seconds: SPR round   2 of   2, 1701 of 4154 nodes
#      15.57 seconds: SPR round   2 of   2, 1801 of 4154 nodes
#      15.70 seconds: SPR round   2 of   2, 1901 of 4154 nodes
#      15.84 seconds: SPR round   2 of   2, 2001 of 4154 nodes
#      15.96 seconds: SPR round   2 of   2, 2101 of 4154 nodes
#      16.09 seconds: SPR round   2 of   2, 2201 of 4154 nodes
#      16.21 seconds: SPR round   2 of   2, 2301 of 4154 nodes
#      16.33 seconds: SPR round   2 of   2, 2401 of 4154 nodes
#      16.46 seconds: SPR round   2 of   2, 2501 of 4154 nodes
#      16.64 seconds: SPR round   2 of   2, 2601 of 4154 nodes
#      16.83 seconds: SPR round   2 of   2, 2701 of 4154 nodes
#      17.01 seconds: SPR round   2 of   2, 2801 of 4154 nodes
#      17.19 seconds: SPR round   2 of   2, 2901 of 4154 nodes
#      17.37 seconds: SPR round   2 of   2, 3001 of 4154 nodes
#      17.52 seconds: SPR round   2 of   2, 3101 of 4154 nodes
#      17.71 seconds: SPR round   2 of   2, 3201 of 4154 nodes
#      17.86 seconds: SPR round   2 of   2, 3301 of 4154 nodes
#      17.99 seconds: SPR round   2 of   2, 3401 of 4154 nodes
#      18.16 seconds: SPR round   2 of   2, 3501 of 4154 nodes
#      18.28 seconds: SPR round   2 of   2, 3601 of 4154 nodes
#      18.40 seconds: SPR round   2 of   2, 3701 of 4154 nodes
#      18.55 seconds: SPR round   2 of   2, 3801 of 4154 nodes
#      18.68 seconds: SPR round   2 of   2, 3901 of 4154 nodes
#      18.83 seconds: SPR round   2 of   2, 4001 of 4154 nodes
#      18.97 seconds: SPR round   2 of   2, 4101 of 4154 nodes
#      19.07 seconds: ME NNI round 29 of 44, 601 of 2076 splits, 2 changes (max delta 0.001)
#      19.17 seconds: ME NNI round 29 of 44, 2001 of 2076 splits, 8 changes (max delta 0.007)
#      19.27 seconds: ME NNI round 30 of 44, 1301 of 2076 splits, 2 changes (max delta 0.008)
# Total branch-length 122.037 after 19.58 sec
#      19.61 seconds: ML Lengths 1 of 2076 splits
#      19.79 seconds: ML Lengths 201 of 2076 splits
#      19.95 seconds: ML Lengths 401 of 2076 splits
#      20.12 seconds: ML Lengths 601 of 2076 splits
#      20.28 seconds: ML Lengths 801 of 2076 splits
#      20.44 seconds: ML Lengths 1001 of 2076 splits
#      20.60 seconds: ML Lengths 1201 of 2076 splits
#      20.70 seconds: ML Lengths 1301 of 2076 splits
#      20.80 seconds: ML Lengths 1401 of 2076 splits
#      20.99 seconds: ML Lengths 1601 of 2076 splits
#      21.16 seconds: ML Lengths 1801 of 2076 splits
#      21.32 seconds: ML Lengths 2001 of 2076 splits
#      21.67 seconds: ML NNI round 1 of 22, 101 of 2076 splits, 20 changes (max delta 7.805)
#      21.95 seconds: ML NNI round 1 of 22, 201 of 2076 splits, 41 changes (max delta 12.903)
#      22.23 seconds: ML NNI round 1 of 22, 301 of 2076 splits, 55 changes (max delta 12.903)
#      22.52 seconds: ML NNI round 1 of 22, 401 of 2076 splits, 67 changes (max delta 12.903)
#      22.80 seconds: ML NNI round 1 of 22, 501 of 2076 splits, 81 changes (max delta 12.903)
#      23.09 seconds: ML NNI round 1 of 22, 601 of 2076 splits, 100 changes (max delta 12.903)
#      23.39 seconds: ML NNI round 1 of 22, 701 of 2076 splits, 125 changes (max delta 12.903)
#      23.73 seconds: ML NNI round 1 of 22, 801 of 2076 splits, 141 changes (max delta 12.903)
#      24.10 seconds: ML NNI round 1 of 22, 901 of 2076 splits, 152 changes (max delta 12.903)
#      24.44 seconds: ML NNI round 1 of 22, 1001 of 2076 splits, 169 changes (max delta 12.903)
#      24.73 seconds: ML NNI round 1 of 22, 1101 of 2076 splits, 186 changes (max delta 12.903)
#      24.99 seconds: ML NNI round 1 of 22, 1201 of 2076 splits, 200 changes (max delta 12.903)
#      25.26 seconds: ML NNI round 1 of 22, 1301 of 2076 splits, 223 changes (max delta 12.903)
#      25.56 seconds: ML NNI round 1 of 22, 1401 of 2076 splits, 236 changes (max delta 12.903)
#      25.85 seconds: ML NNI round 1 of 22, 1501 of 2076 splits, 248 changes (max delta 12.903)
#      26.19 seconds: ML NNI round 1 of 22, 1601 of 2076 splits, 271 changes (max delta 12.903)
#      26.53 seconds: ML NNI round 1 of 22, 1701 of 2076 splits, 293 changes (max delta 12.903)
#      26.83 seconds: ML NNI round 1 of 22, 1801 of 2076 splits, 313 changes (max delta 12.903)
#      27.11 seconds: ML NNI round 1 of 22, 1901 of 2076 splits, 330 changes (max delta 12.903)
#      27.39 seconds: ML NNI round 1 of 22, 2001 of 2076 splits, 352 changes (max delta 12.903)
# ML-NNI round 1: LogLk = -140658.725 NNIs 364 max delta 12.90 Time 27.66
#      27.78 seconds: Site likelihoods with rate category 1 of 20
#      27.91 seconds: Site likelihoods with rate category 2 of 20
#      28.04 seconds: Site likelihoods with rate category 3 of 20
#      28.18 seconds: Site likelihoods with rate category 4 of 20
#      28.31 seconds: Site likelihoods with rate category 5 of 20
#      28.41 seconds: Site likelihoods with rate category 6 of 20
#      28.52 seconds: Site likelihoods with rate category 7 of 20
#      28.62 seconds: Site likelihoods with rate category 8 of 20
#      28.72 seconds: Site likelihoods with rate category 9 of 20
#      28.83 seconds: Site likelihoods with rate category 10 of 20
#      28.93 seconds: Site likelihoods with rate category 11 of 20
#      29.03 seconds: Site likelihoods with rate category 12 of 20
#      29.14 seconds: Site likelihoods with rate category 13 of 20
#      29.24 seconds: Site likelihoods with rate category 14 of 20
#      29.34 seconds: Site likelihoods with rate category 15 of 20
#      29.45 seconds: Site likelihoods with rate category 16 of 20
#      29.55 seconds: Site likelihoods with rate category 17 of 20
#      29.65 seconds: Site likelihoods with rate category 18 of 20
#      29.76 seconds: Site likelihoods with rate category 19 of 20
#      29.86 seconds: Site likelihoods with rate category 20 of 20
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 0.942 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
#      30.09 seconds: ML NNI round 2 of 22, 101 of 2076 splits, 10 changes (max delta 0.161)
#      30.28 seconds: ML NNI round 2 of 22, 201 of 2076 splits, 21 changes (max delta 1.331)
#      30.48 seconds: ML NNI round 2 of 22, 301 of 2076 splits, 31 changes (max delta 3.879)
#      30.66 seconds: ML NNI round 2 of 22, 401 of 2076 splits, 40 changes (max delta 3.879)
#      30.87 seconds: ML NNI round 2 of 22, 501 of 2076 splits, 43 changes (max delta 3.879)
#      31.07 seconds: ML NNI round 2 of 22, 601 of 2076 splits, 57 changes (max delta 5.022)
#      31.25 seconds: ML NNI round 2 of 22, 701 of 2076 splits, 65 changes (max delta 5.022)
#      31.44 seconds: ML NNI round 2 of 22, 801 of 2076 splits, 70 changes (max delta 5.022)
#      31.69 seconds: ML NNI round 2 of 22, 901 of 2076 splits, 80 changes (max delta 5.022)
#      31.91 seconds: ML NNI round 2 of 22, 1001 of 2076 splits, 93 changes (max delta 5.022)
#      32.12 seconds: ML NNI round 2 of 22, 1101 of 2076 splits, 110 changes (max delta 5.022)
#      32.32 seconds: ML NNI round 2 of 22, 1201 of 2076 splits, 123 changes (max delta 5.022)
#      32.50 seconds: ML NNI round 2 of 22, 1301 of 2076 splits, 133 changes (max delta 7.159)
#      32.70 seconds: ML NNI round 2 of 22, 1401 of 2076 splits, 146 changes (max delta 7.159)
#      32.88 seconds: ML NNI round 2 of 22, 1501 of 2076 splits, 161 changes (max delta 7.159)
#      33.10 seconds: ML NNI round 2 of 22, 1601 of 2076 splits, 165 changes (max delta 7.159)
#      33.32 seconds: ML NNI round 2 of 22, 1701 of 2076 splits, 173 changes (max delta 7.159)
#      33.53 seconds: ML NNI round 2 of 22, 1801 of 2076 splits, 180 changes (max delta 7.159)
#      33.73 seconds: ML NNI round 2 of 22, 1901 of 2076 splits, 189 changes (max delta 7.159)
#      33.94 seconds: ML NNI round 2 of 22, 2001 of 2076 splits, 196 changes (max delta 7.159)
# ML-NNI round 2: LogLk = -130463.084 NNIs 202 max delta 7.16 Time 34.21
#      34.21 seconds: ML NNI round 3 of 22, 1 of 2076 splits
#      34.41 seconds: ML NNI round 3 of 22, 101 of 2076 splits, 5 changes (max delta 2.478)
#      34.60 seconds: ML NNI round 3 of 22, 201 of 2076 splits, 11 changes (max delta 2.478)
#      34.75 seconds: ML NNI round 3 of 22, 301 of 2076 splits, 17 changes (max delta 4.500)
#      34.94 seconds: ML NNI round 3 of 22, 401 of 2076 splits, 23 changes (max delta 4.500)
#      35.15 seconds: ML NNI round 3 of 22, 501 of 2076 splits, 31 changes (max delta 4.500)
#      35.56 seconds: ML NNI round 3 of 22, 601 of 2076 splits, 39 changes (max delta 4.500)
#      35.79 seconds: ML NNI round 3 of 22, 701 of 2076 splits, 43 changes (max delta 4.500)
#      35.95 seconds: ML NNI round 3 of 22, 801 of 2076 splits, 43 changes (max delta 4.500)
#      36.14 seconds: ML NNI round 3 of 22, 901 of 2076 splits, 49 changes (max delta 4.500)
#      36.32 seconds: ML NNI round 3 of 22, 1001 of 2076 splits, 52 changes (max delta 4.500)
#      36.48 seconds: ML NNI round 3 of 22, 1101 of 2076 splits, 54 changes (max delta 4.500)
#      36.64 seconds: ML NNI round 3 of 22, 1201 of 2076 splits, 57 changes (max delta 4.500)
# ML-NNI round 3: LogLk = -130401.007 NNIs 64 max delta 4.50 Time 36.88
#      36.87 seconds: ML NNI round 4 of 22, 1 of 2076 splits
#      37.03 seconds: ML NNI round 4 of 22, 101 of 2076 splits, 5 changes (max delta 3.657)
#      37.20 seconds: ML NNI round 4 of 22, 201 of 2076 splits, 8 changes (max delta 3.657)
#      37.32 seconds: ML NNI round 4 of 22, 301 of 2076 splits, 9 changes (max delta 3.657)
#      37.56 seconds: ML NNI round 4 of 22, 401 of 2076 splits, 13 changes (max delta 3.657)
#      37.68 seconds: ML NNI round 4 of 22, 501 of 2076 splits, 13 changes (max delta 3.657)
#      37.83 seconds: ML NNI round 4 of 22, 601 of 2076 splits, 13 changes (max delta 3.657)
# ML-NNI round 4: LogLk = -130381.799 NNIs 16 max delta 3.66 Time 38.06
#      38.06 seconds: ML NNI round 5 of 22, 1 of 2076 splits
#      38.19 seconds: ML NNI round 5 of 22, 101 of 2076 splits, 1 changes (max delta 0.521)
#      38.42 seconds: ML NNI round 5 of 22, 201 of 2076 splits, 2 changes (max delta 0.521)
#      38.58 seconds: ML NNI round 5 of 22, 301 of 2076 splits, 4 changes (max delta 0.521)
# ML-NNI round 5: LogLk = -130372.395 NNIs 4 max delta 0.52 Time 38.72
#      38.72 seconds: ML NNI round 6 of 22, 1 of 2076 splits
#      38.88 seconds: ML NNI round 6 of 22, 101 of 2076 splits, 1 changes (max delta 0.267)
# ML-NNI round 6: LogLk = -130371.763 NNIs 1 max delta 0.27 Time 38.98
#      38.98 seconds: ML NNI round 7 of 22, 1 of 2076 splits
# ML-NNI round 7: LogLk = -130371.751 NNIs 0 max delta 0.00 Time 39.13
# Turning off heuristics for final round of ML NNIs (converged)
#      39.12 seconds: ML NNI round 8 of 22, 1 of 2076 splits
#      39.38 seconds: ML NNI round 8 of 22, 101 of 2076 splits, 1 changes (max delta 0.000)
#      39.62 seconds: ML NNI round 8 of 22, 201 of 2076 splits, 1 changes (max delta 0.000)
#      39.87 seconds: ML NNI round 8 of 22, 301 of 2076 splits, 5 changes (max delta 1.638)
#      40.13 seconds: ML NNI round 8 of 22, 401 of 2076 splits, 6 changes (max delta 1.638)
#      40.39 seconds: ML NNI round 8 of 22, 501 of 2076 splits, 8 changes (max delta 3.912)
#      40.71 seconds: ML NNI round 8 of 22, 601 of 2076 splits, 10 changes (max delta 3.912)
#      41.04 seconds: ML NNI round 8 of 22, 701 of 2076 splits, 12 changes (max delta 6.587)
#      41.40 seconds: ML NNI round 8 of 22, 801 of 2076 splits, 13 changes (max delta 6.587)
#      41.79 seconds: ML NNI round 8 of 22, 901 of 2076 splits, 15 changes (max delta 6.587)
#      42.15 seconds: ML NNI round 8 of 22, 1001 of 2076 splits, 15 changes (max delta 6.587)
#      42.44 seconds: ML NNI round 8 of 22, 1101 of 2076 splits, 16 changes (max delta 6.587)
#      42.71 seconds: ML NNI round 8 of 22, 1201 of 2076 splits, 17 changes (max delta 6.587)
#      43.00 seconds: ML NNI round 8 of 22, 1301 of 2076 splits, 20 changes (max delta 6.587)
#      43.35 seconds: ML NNI round 8 of 22, 1401 of 2076 splits, 21 changes (max delta 6.587)
#      43.62 seconds: ML NNI round 8 of 22, 1501 of 2076 splits, 23 changes (max delta 6.587)
#      43.93 seconds: ML NNI round 8 of 22, 1601 of 2076 splits, 23 changes (max delta 6.587)
#      44.23 seconds: ML NNI round 8 of 22, 1701 of 2076 splits, 25 changes (max delta 6.587)
#      44.49 seconds: ML NNI round 8 of 22, 1801 of 2076 splits, 25 changes (max delta 6.587)
#      44.78 seconds: ML NNI round 8 of 22, 1901 of 2076 splits, 25 changes (max delta 6.587)
#      45.08 seconds: ML NNI round 8 of 22, 2001 of 2076 splits, 27 changes (max delta 6.587)
# ML-NNI round 8: LogLk = -130244.090 NNIs 27 max delta 6.59 Time 45.40 (final)
#      45.39 seconds: ML Lengths 1 of 2076 splits
#      45.53 seconds: ML Lengths 201 of 2076 splits
#      45.65 seconds: ML Lengths 401 of 2076 splits
#      45.80 seconds: ML Lengths 601 of 2076 splits
#      45.96 seconds: ML Lengths 801 of 2076 splits
#      46.11 seconds: ML Lengths 1001 of 2076 splits
#      46.26 seconds: ML Lengths 1201 of 2076 splits
#      46.41 seconds: ML Lengths 1401 of 2076 splits
#      46.56 seconds: ML Lengths 1601 of 2076 splits
#      46.70 seconds: ML Lengths 1801 of 2076 splits
#      46.84 seconds: ML Lengths 2001 of 2076 splits
# Optimize all lengths: LogLk = -130235.015 Time 46.98
#      47.38 seconds: ML split tests for    100 of   2075 internal splits
#      47.79 seconds: ML split tests for    200 of   2075 internal splits
#      48.18 seconds: ML split tests for    300 of   2075 internal splits
#      48.57 seconds: ML split tests for    400 of   2075 internal splits
#      48.98 seconds: ML split tests for    500 of   2075 internal splits
#      49.38 seconds: ML split tests for    600 of   2075 internal splits
#      49.85 seconds: ML split tests for    700 of   2075 internal splits
#      50.33 seconds: ML split tests for    800 of   2075 internal splits
#      50.78 seconds: ML split tests for    900 of   2075 internal splits
#      51.20 seconds: ML split tests for   1000 of   2075 internal splits
#      51.57 seconds: ML split tests for   1100 of   2075 internal splits
#      51.97 seconds: ML split tests for   1200 of   2075 internal splits
#      52.42 seconds: ML split tests for   1300 of   2075 internal splits
#      52.83 seconds: ML split tests for   1400 of   2075 internal splits
#      53.22 seconds: ML split tests for   1500 of   2075 internal splits
#      53.63 seconds: ML split tests for   1600 of   2075 internal splits
#      54.07 seconds: ML split tests for   1700 of   2075 internal splits
#      54.47 seconds: ML split tests for   1800 of   2075 internal splits
#      54.92 seconds: ML split tests for   1900 of   2075 internal splits
#      55.39 seconds: ML split tests for   2000 of   2075 internal splits
# Total time: 55.73 seconds Unique: 2078/2242 Bad splits: 1/2075 Worst delta-LogLk 6.883

# %%
alignment.save("output/qza/alignment") 
masked_alignment.save("output/qza/masked_alignment")
tree.save("output/qza/tree")
rooted_tree.save("output/qza/rooted_tree")
# Out:
# 'output/qza/rooted_tree.qza'
